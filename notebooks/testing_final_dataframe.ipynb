# %%
import sys
import pandas as pd
import numpy as np
from pathlib import Path

# %%
current_dir = Path().cwd()
project_root = current_dir.parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
    print('done')
# Out:
# done

# %%
from src.utils.save_data import load_df_parquet_safe, save_df_parquet_safe
from src.utils.datamodels import Blink

# %%
path = project_root / "data" / "processed" / "merge" / "final_dataframe.parquet"
f_df = load_df_parquet_safe(path=str(path))

# %%
sample = f_df.head()

# %%
a=f_df['blinking_data'].iloc[0]

# %%
data_model = Blink(**a)

# %%
data_model
# Out:
# Blink(intensity=None, asymmetry=None, is_blinking=True, rz_score=3.57146416776886, is_anomalous=False, continuos_anomaly=False, part_of_anomalous_range=None)

# %% [markdown]
# #### Let'ss gooo it's working fineee...🔥🔥🔥

# %% [markdown]
# Saving a sample of final_dataframe

# %%
path = project_root / "data" / "processed" / "sample" / "final_df_sample.parquet"
save_df_parquet_safe(df=sample, path=str(path))
# Out:
# Saved Parquet: c:\Users\BIT\Desktop\mmr\data\processed\sample\final_df_sample.parquet
# Saved schema: c:\Users\BIT\Desktop\mmr\data\processed\sample\final_df_sample.parquet.schema.json

# %%
sample
# Out:
#                                        blinking_data  \
# 0  {'intensity': None, 'asymmetry': None, 'is_bli...
# 1  {'intensity': None, 'asymmetry': None, 'is_bli...
# 2  {'intensity': None, 'asymmetry': None, 'is_bli...
# 3  {'intensity': None, 'asymmetry': None, 'is_bli...
# 4  {'intensity': None, 'asymmetry': None, 'is_bli...
#
#                                            gaze_data  \
# 0  {'horizontal_deviation': None, 'vertical_devia...
# 1  {'horizontal_deviation': None, 'vertical_devia...
# 2  {'horizontal_deviation': None, 'vertical_devia...
# 3  {'horizontal_deviation': None, 'vertical_devia...
# 4  {'horizontal_deviation': None, 'vertical_devia...
#
#                                    jaw_movement_data  \
# 0  {'open': 0.023826630786061287, 'lateral': None...
# 1  {'open': 0.01953260414302349, 'lateral': None,...
# 2  {'open': 0.0008870773017406464, 'lateral': Non...
# 3  {'open': 0.0015012087533250451, 'lateral': Non...
# ...
