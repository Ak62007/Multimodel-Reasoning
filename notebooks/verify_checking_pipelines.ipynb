# %% [markdown]
# # Loading all Visual data

# %% [markdown]
# ### Defining path

# %%
from pathlib import Path

current_dir = Path.cwd()

project_root = current_dir.parent

VIDEOPATH = project_root / "data" / "raw" / "Interview_2.mp4"
OUTPUTPATH = project_root / "data" / "processed" / "Interview_2_frames"
MODELPATH = project_root / "models" / "face_landmarker.task"
AUDIOPATH = project_root / "data" / "raw" / "Interview_2.wav"

# %%
import os
import sys

parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
print(parent_dir)

if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)
    print("ho gaya")
# Out:
# c:\Users\BIT\Desktop\mmr

# %%
from src.video.frame_extractor import extract_frames
from src.video.face_features_ts_data import face_analysis_data
from src.audio.technical_data import analyze_audio_layers
from src.audio.utterances_data import get_utterances_data
from src.audio.whisper_data import get_whisper_data
# Out:
# Importing the dtw module. When using in academic works please cite:
#   T. Giorgino. Computing and Visualizing Dynamic Time Warping Alignments in R: The dtw Package.
#   J. Stat. Soft., doi:10.18637/jss.v031.i07.

# %%
extract_frames(video_path=str(VIDEOPATH), output_path=str(OUTPUTPATH))

# %%
v_data = face_analysis_data(model_path=str(MODELPATH), images_path=str(OUTPUTPATH))
# Out:
# c:\Users\BIT\Desktop\mmr\.venv\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '

# %%
v_data.columns
# Out:
# Index(['Time', 'h_ratio', 'v_ratio', '_neutral', 'browDownLeft',
#        'browDownRight', 'browInnerUp', 'browOuterUpLeft', 'browOuterUpRight',
#        'cheekPuff', 'cheekSquintLeft', 'cheekSquintRight', 'eyeBlinkLeft',
#        'eyeBlinkRight', 'eyeLookDownLeft', 'eyeLookDownRight', 'eyeLookInLeft',
#        'eyeLookInRight', 'eyeLookOutLeft', 'eyeLookOutRight', 'eyeLookUpLeft',
#        'eyeLookUpRight', 'eyeSquintLeft', 'eyeSquintRight', 'eyeWideLeft',
#        'eyeWideRight', 'jawForward', 'jawLeft', 'jawOpen', 'jawRight',
#        'mouthClose', 'mouthDimpleLeft', 'mouthDimpleRight', 'mouthFrownLeft',
#        'mouthFrownRight', 'mouthFunnel', 'mouthLeft', 'mouthLowerDownLeft',
#        'mouthLowerDownRight', 'mouthPressLeft', 'mouthPressRight',
#        'mouthPucker', 'mouthRight', 'mouthRollLower', 'mouthRollUpper',
#        'mouthShrugLower', 'mouthShrugUpper', 'mouthSmileLeft',
#        'mouthSmileRight', 'mouthStretchLeft', 'mouthStretchRight',
#        'mouthUpperUpLeft', 'mouthUpperUpRight', 'noseSneerLeft',
#        'noseSneerRight'],
#       dtype='object')

# %%
# Temporal Visual Data
v_data.head()
# Out:
#    Time   h_ratio   v_ratio  ...  mouthUpperUpRight  noseSneerLeft  noseSneerRight
# 0   0.0  0.463844  0.012997  ...           0.000022   4.540787e-07    4.185384e-07
# 1   1.0  0.465044 -0.030748  ...           0.000269   2.899701e-06    1.134860e-07
# 2   2.0  0.590369 -0.050514  ...           0.000476   4.304491e-06    2.317813e-07
# 3   3.0  0.444558 -0.010890  ...           0.000002   3.736344e-07    3.246403e-07
# 4   4.0  0.420816 -0.037800  ...           0.000009   3.077891e-07    4.113523e-07
#
# [5 rows x 55 columns]

# %% [markdown]
# # Loading all the audio data, Testing all the function along side

# %%
t_data = analyze_audio_layers(audio_path=str(AUDIOPATH))

# %%
t_data.columns
# Out:
# Index(['Time', 'audio_rms(volumn)', 'audio_pitch_avg',
#        'audio_pitch_var(expressiveness)', 'is_silent'],
#       dtype='object')

# %%
t_data.head()
# Out:
#    Time  audio_rms(volumn)  ...  audio_pitch_var(expressiveness)  is_silent
# 0   0.0             0.0373  ...                             0.00      False
# 1   0.5             0.0533  ...                            11.45      False
# 2   1.0             0.0006  ...                             0.00       True
# 3   1.5             0.0593  ...                            14.03      False
# 4   2.0             0.0646  ...                            56.17      False
#
# [5 rows x 5 columns]

# %%
import os
from dotenv import load_dotenv
load_dotenv()
api_key = os.getenv('ASSEMBLYAI_API_KEY')
u_data = get_utterances_data(api_key=api_key, audio_path=str(AUDIOPATH))
# Out:
# Uploading and transcribing...
# Transcription complete!

# %%
u_data.columns
# Out:
# Index(['text', 'start', 'end', 'confidence', 'speaker', 'channel', 'words',
#        'translated_texts'],
#       dtype='object')

# %%
u_data.head()
# Out:
#                                                 text  ...  translated_texts
# 0  Alright, we're starting now, so welcome to the...  ...              None
# 1  Yeah, so like right now I'm in third year of m...  ...              None
# 2  That's a great background and it's always awes...  ...              None
# 3  Yeah, so handling or cleaning the data set is ...  ...              None
# 4            Those are not always the right choices.  ...              None
#
# [5 rows x 8 columns]

# %%
w_data = get_whisper_data(audio_path=str(AUDIOPATH))
# Out:
# Detected language: English
# 100%|██████████| 63183/63183 [06:46<00:00, 155.50frames/s]

# %%
w_data.columns
# Out:
# Index(['id', 'seek', 'start', 'end', 'text', 'tokens', 'temperature',
#        'avg_logprob', 'compression_ratio', 'no_speech_prob', 'confidence',
#        'words'],
#       dtype='object')

# %%
w_data.head()
# Out:
#    id  seek  ...  confidence                                              words
# 0   0     0  ...       0.837  [{'text': 'We're', 'start': 0.0, 'end': 0.32, ...
# 1   1     0  ...       0.973  [{'text': 'me', 'start': 5.69, 'end': 5.86, 'c...
# 2   2     0  ...       0.887  [{'text': 'Yeah,', 'start': 11.18, 'end': 11.3...
# 3   3     0  ...       0.906  [{'text': 'but', 'start': 18.76, 'end': 19.12,...
# 4   4  2584  ...       0.885  [{'text': 'I', 'start': 25.94, 'end': 26.2, 'c...
#
# [5 rows x 12 columns]
